# %% [markdown]
# Example 1 - Image Classification with Convolutional Neural Networks (CNN) using TensorFlow and Keras
#
#     Convolutional layers: Detect patterns in images
#     Pooling layers: Reduce dimensionality and complexity
#     Fully connected layers: Combine features for final classification

# %% [markdown]
# Dataset: https://www.cs.toronto.edu/~kriz/cifar.html
# Images showing objects from 10 different classse
#
# Task: Train NN to recognize images

# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models

# Load and preprocess data
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()
train_images, test_images = train_images / 255.0, test_images / 255.0

# Define CNN model
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))

# Compile and train the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(train_images, train_labels, epochs=10, validation_data=(test_images, test_labels))

# Evaluate the model
test_loss, test_acc = model.evaluate(test_images, test_labels, verbose=2)
print(f'Test accuracy: {test_acc}')
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 15s 9ms/step - loss: 1.5003 - accuracy: 0.4538 - val_loss: 1.3041 - val_accuracy: 0.5405
# Epoch 2/10
# 1563/1563 [==============================] - 14s 9ms/step - loss: 1.1296 - accuracy: 0.6007 - val_loss: 1.0701 - val_accuracy: 0.6269
# Epoch 3/10
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.9821 - accuracy: 0.6550 - val_loss: 0.9719 - val_accuracy: 0.6640
# Epoch 4/10
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.8835 - accuracy: 0.6888 - val_loss: 0.9905 - val_accuracy: 0.6577
# Epoch 5/10
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.8147 - accuracy: 0.7152 - val_loss: 0.8806 - val_accuracy: 0.6964
# Epoch 6/10
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.7631 - accuracy: 0.7315 - val_loss: 0.8673 - val_accuracy: 0.6996
# Epoch 7/10
# ...

# %% [markdown]
# Example 2 - Sentiment Analysis with Recurrent Neural Networks (RNN) using TensorFlow and Keras
#
#     RNNs can process sequences of variable length
#     LSTM (Long Short-Term Memory) layers: Address vanishing gradient problem
#     GRU (Gated Recurrent Unit) layers: Simplified version of LSTM

# %% [markdown]
# Dataset: IMDB database of movies
# https://www.kaggle.com/code/lakshmi25npathi/sentiment-analysis-of-imdb-movie-reviews/input
# Task: Predict sentiment based on the movie review

# %%
import tensorflow as tf
from tensorflow.keras import layers, preprocessing, utils
from tensorflow.keras.datasets import imdb

# Load and preprocess data
max_features = 10000
max_len = 500

(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=max_features)
train_data = preprocessing.sequence.pad_sequences(train_data, maxlen=max_len)
test_data = preprocessing.sequence.pad_sequences(test_data, maxlen=max_len)

# Define RNN model with LSTM layer
model = tf.keras.Sequential()
model.add(layers.Embedding(max_features, 32))
model.add(layers.LSTM(32))
model.add(layers.Dense(1, activation='sigmoid'))

# Compile and train the model
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])
history = model.fit(train_data, train_labels, epochs=10, batch_size=128, validation_split=0.2)

# Evaluate the model
test_loss, test_acc = model.evaluate(test_data, test_labels, verbose=2)
print(f'Test accuracy: {test_acc}')
# Out:
# ...
# 17464789/17464789 [==============================] - 0s 0us/step
# Epoch 1/10
# 157/157 [==============================] - 26s 161ms/step - loss: 0.6056 - accuracy: 0.6641 - val_loss: 0.4904 - val_accuracy: 0.8026
# Epoch 2/10
# 157/157 [==============================] - 25s 161ms/step - loss: 0.3619 - accuracy: 0.8528 - val_loss: 0.3140 - val_accuracy: 0.8748
# Epoch 3/10
# 157/157 [==============================] - 25s 161ms/step - loss: 0.2866 - accuracy: 0.8855 - val_loss: 0.2949 - val_accuracy: 0.8802
# Epoch 4/10
# 157/157 [==============================] - 25s 161ms/step - loss: 0.2407 - accuracy: 0.9077 - val_loss: 0.3020 - val_accuracy: 0.8804
# Epoch 5/10
# 157/157 [==============================] - 26s 163ms/step - loss: 0.2097 - accuracy: 0.9211 - val_loss: 0.3198 - val_accuracy: 0.8658
# Epoch 6/10
# 157/157 [==============================] - 25s 161ms/step - loss: 0.1879 - accuracy: 0.9330 - val_loss: 0.3242 - val_accuracy: 0.8756
# Epoch 7/10
# ...
